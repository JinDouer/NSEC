# %%
##flip vertically and horizantol

# %%
import numpy as np
import os
import sys
import time
import argparse
import json
from PIL import Image
import matplotlib.pyplot as plt
import torchvision
import torch
import torch.utils.data as data
import torch.optim as optim
from torch.autograd import Variable,Function
sys.path.insert(0,'/home/prisimage/tracker/py-MDNetST/modules')
from sample_generator import *
from data_prov import *
from model import *
from bbreg import *
from options import *
from gen_config import *
from sklearn.neighbors import NearestNeighbors
from scipy.spatial.distance import cdist
class PairwiseDistance(nn.Module):
    def __init__(self):
        super(PairwiseDistance, self).__init__()
        

    def forward(self, x1, x2):
        x2 = torch.unsqueeze(x2,dim=1)
        diff = x2 - x1
        dist = torch.pow(diff,2).sum(dim=2)
        dist = dist/torch.max(dist,dim=0)[0]
        distance = torch.mean(dist)
        #distance = torch.sum(dist)
        return distance
def show_bbox(image,bboxes):
    dpi = 80.0
    figsize = (image.size[0]/dpi, image.size[1]/dpi)

    fig = plt.figure(frameon=False, figsize=figsize, dpi=dpi)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    im = ax.imshow(image, aspect=1)
    for i in range(len(bboxes)):
        rect = plt.Rectangle(tuple(bboxes[i,:2]),bboxes[i,2],bboxes[i,3], 
                             linewidth=1, edgecolor="#ff0000", zorder=1, fill=False)
        ax.add_patch(rect)
def show_result(image,bbox):
    dpi = 80.0
    figsize = (image.size[0]/dpi, image.size[1]/dpi)

    fig = plt.figure(frameon=False, figsize=figsize, dpi=dpi)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    im = ax.imshow(image, aspect=1)
    rect = plt.Rectangle(tuple(bbox[:2]),bbox[2],bbox[3], linewidth=1, edgecolor="#ff0000", zorder=1, fill=False)
    ax.add_patch(rect)
def show_grid(image,samples,num):
    image = np.asarray(image)
    sample_arr = list()
    image = np.asarray(image)
    for i in range(num):
        sample_img = crop_image(image,samples[i],107,0)
        sample_arr.append(sample_img)
    d = np.stack(sample_arr,axis=0)
    torch_img = torchvision.utils.make_grid(torch.from_numpy(np.transpose(d,(0,3,1,2))))
    npimg = torch_img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
def set_optimizer(model, lr_base, lr_mult=opts['lr_mult'], momentum=opts['momentum'], w_decay=opts['w_decay']):
    params = model.get_learnable_params()
    param_list = []
    for k, p in params.iteritems():
        lr = lr_base
        for l, m in lr_mult.iteritems():
            if k.startswith(l):
                lr = lr_base * m
        param_list.append({'params': [p], 'lr':lr})
    optimizer = optim.SGD(param_list, lr = lr, momentum=momentum, weight_decay=w_decay)
    return optimizer
def show_bbox(image,bboxes):
    dpi = 80.0
    figsize = (image.size[0]/dpi, image.size[1]/dpi)

    fig = plt.figure(frameon=False, figsize=figsize, dpi=dpi)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    im = ax.imshow(image, aspect=1)
    for i in range(len(bboxes)):
        rect = plt.Rectangle(tuple(bboxes[i,:2]),bboxes[i,2],bboxes[i,3], 
                             linewidth=1, edgecolor="#ff0000", zorder=1, fill=False)
        ax.add_patch(rect)
def show_result(image,bbox):
    dpi = 80.0
    figsize = (image.size[0]/dpi, image.size[1]/dpi)

    fig = plt.figure(frameon=False, figsize=figsize, dpi=dpi)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    im = ax.imshow(image, aspect=1)
    rect = plt.Rectangle(tuple(bbox[:2]),bbox[2],bbox[3], linewidth=1, edgecolor="#ff0000", zorder=1, fill=False)
    ax.add_patch(rect)
def forward_samples(model, image, samples, out_layer='conv3'):
    model.eval()
    extractor = RegionExtractor(image, samples, opts['img_size'], opts['padding'], opts['batch_test'])
    for i, regions in enumerate(extractor):
        regions = Variable(regions)
        if opts['use_gpu']:
            regions = regions.cuda()
        feat = model(regions, out_layer=out_layer)
        if i==0:
            feats = feat.data.clone()
        else:
            feats = torch.cat((feats,feat.data.clone()),0)
    return feats
def train(model, pdist, optimizer, pos_feats, neg_feats, maxiter, in_layer='fc4'):
    model.train()
    
    batch_pos = opts['batch_pos']
    batch_neg = opts['batch_neg']
    batch_test = opts['batch_test']
    #batch_neg_cand = max(opts['batch_neg_cand'], batch_neg)

    pos_idx = np.random.permutation(pos_feats.size(0))
    neg_idx = np.random.permutation(neg_feats.size(0))
    while(len(pos_idx) < batch_pos*maxiter):
        pos_idx = np.concatenate([pos_idx, np.random.permutation(pos_feats.size(0))])
    while(len(neg_idx) < batch_neg*maxiter):
        neg_idx = np.concatenate([neg_idx, np.random.permutation(neg_feats.size(0))])
    pos_pointer = 0
    neg_pointer = 0

    for iter in range(maxiter):

        # select pos idx
        pos_next = pos_pointer+batch_pos
        pos_cur_idx = pos_idx[pos_pointer:pos_next]
        pos_cur_idx = pos_feats.new(pos_cur_idx).long()
        pos_pointer = pos_next

        # select neg idx
        neg_next = neg_pointer+batch_neg
        neg_cur_idx = neg_idx[neg_pointer:neg_next]
        neg_cur_idx = neg_feats.new(neg_cur_idx).long()
        neg_pointer = neg_next

        # create batch
        batch_pos_feats = Variable(pos_feats.index_select(0, pos_cur_idx))
        batch_neg_feats = Variable(neg_feats.index_select(0, neg_cur_idx))

        
        # forward
        
        neg_fc5 = model(batch_neg_feats, in_layer=in_layer,out_layer='fc5')
        pos_fc5 = model(batch_pos_feats, in_layer=in_layer,out_layer='fc5')
        # optimize
        p_loss = 3*pdist(pos_fc5,pos_fc5)
        n_loss = 1-pdist(pos_fc5,neg_fc5)
        loss = p_loss+n_loss
        print(loss)
        model.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm(model.parameters(), opts['grad_clip'])
        optimizer.step()

        #print "Iter %d, Loss %.4f" % (iter, loss.data[0])
#import cv2
def cvshow(img):
    cv2.imshow("Image",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    

        

np.random.seed(123)
torch.manual_seed(456)
torch.cuda.manual_seed(789)
seq_home = '../dataset/OTB'
save_home = '../result_fig'
result_home = '../result'
        
seq_name = 'Skiing'
img_dir = os.path.join(seq_home, seq_name, 'img')
gt_path = os.path.join(seq_home, seq_name, 'groundtruth_rect.txt')

img_list = os.listdir(img_dir)
img_list.sort()
img_list = [os.path.join(img_dir,x) for x in img_list]

gt = np.loadtxt(gt_path,delimiter=',')
init_bbox = gt[0]
        
savefig_dir = os.path.join(save_home,seq_name)
result_dir = os.path.join(result_home,seq_name)
if not os.path.exists(result_dir):
    os.makedirs(result_dir)
result_path = os.path.join(result_dir,'result.json')
# get imglist,gt
target_bbox = np.array(init_bbox)
result = np.zeros((len(img_list),4))
result_bb = np.zeros((len(img_list),4))
result[0] = target_bbox
result_bb[0] = target_bbox
#init the first target box and result array
#os.environ['CUDA_VISIBLE_DEVICES'] = "1"
model = MDNet(opts['model_path'])
if opts['use_gpu']:
    model = model.cuda()

model.set_learnable_params(opts['ft_layers'])
#init model and set learnable layers
pdist = PairwiseDistance()

update_optimizer = set_optimizer(model, opts['lr_update'])
image = Image.open(img_list[0]).convert('RGB')
bbreg_examples = gen_samples(SampleGenerator('uniform', image.size, 0.3, 1.5, 1.1),target_bbox, opts['n_bbreg'], opts['overlap_bbreg'], opts['scale_bbreg'])
bbreg_feats = forward_samples(model, image, bbreg_examples)
bbreg = BBRegressor(image.size)
bbreg.train(bbreg_feats, bbreg_examples, target_bbox)
#train bbreg
pos_examples1 = gen_samples(SampleGenerator('gaussian', image.size, 1.5, 1.2),target_bbox, opts['n_pos_init'], opts['overlap_pos_init'])
neg_examples = np.concatenate([
                    gen_samples(SampleGenerator('uniform', image.size, 1, 2, 1.1), 
                                target_bbox, opts['n_neg_init']//2, opts['overlap_neg_init']),
                    gen_samples(SampleGenerator('whole', image.size, 0, 1.2, 1.1),
                                target_bbox, opts['n_neg_init']//2, opts['overlap_neg_init'])])
neg_examples = np.random.permutation(neg_examples)
pos_feats1 = forward_samples(model, image, pos_examples1)
neg_feats = forward_samples(model, image, neg_examples)
feat_dim = pos_feats1.size(-1)
#get init pos/neg feats
horizon_image = image.transpose(Image.FLIP_LEFT_RIGHT)
horizon_target = np.array([horizon_image.size[0]-target_bbox[0]-target_bbox[2],target_bbox[1],target_bbox[2],target_bbox[3]])
pos_examples2 = gen_samples(SampleGenerator('gaussian', image.size, 1.5, 1.2),horizon_target, opts['n_pos_init'], opts['overlap_pos_init'])
pos_feats2 = forward_samples(model, horizon_image, pos_examples2)
vertical_image = image.transpose(Image.FLIP_TOP_BOTTOM)
vertical_target = np.array([target_bbox[0],vertical_image.size[1]-target_bbox[1]-target_bbox[3],target_bbox[2],target_bbox[3]])
pos_examples3 = gen_samples(SampleGenerator('gaussian', image.size, 1.5, 1.2),vertical_target, opts['n_pos_init'], opts['overlap_pos_init'])
pos_feats3 = forward_samples(model, vertical_image, pos_examples3)
pos_feats = torch.cat((pos_feats1,pos_feats2,pos_feats3),0)

# %%
pos_feats.size()
# Out:
# torch.Size([306, 4608])

# %%
init_optimizer = set_optimizer(model, opts['lr_init']*500)
train(model, pdist, init_optimizer,pos_feats, neg_feats, 100)
# Out:
# Variable containing:
#  2.3092
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.5160
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.1164
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.9254
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.0351
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.8862
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.8391
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.0217
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.3769
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.1488
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  1.1706
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.9361
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7682
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.8243
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4990
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6861
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7386
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.8059
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7403
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.8131
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5977
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5963
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5572
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6621
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6230
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6108
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6379
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7486
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7103
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5261
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4488
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7708
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4408
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.8387
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5967
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5545
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4979
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4234
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3470
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5253
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7665
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4561
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4469
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6027
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4893
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4114
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7256
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7039
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3176
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4318
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3825
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4410
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7964
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4115
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7001
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3896
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7188
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2529
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4003
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5640
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6198
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7852
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2540
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3608
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4087
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5718
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3177
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.7402
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4999
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5584
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4585
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4662
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4336
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2310
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4948
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3841
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3569
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3132
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4674
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5682
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4992
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5215
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4578
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.4585
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5193
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5454
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6031
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.6739
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3790
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3953
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3777
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3437
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2724
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3296
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3624
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3404
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5233
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2348
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.2674
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.3759
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %%
sample_generator = SampleGenerator('gaussian', image.size, 0.6, 1.05, valid=True)
i=0
t_bbox = target_bbox[np.newaxis,:]
init_image = Image.open(img_list[0]).convert('RGB')
target_feat_fc5 = forward_samples(model,init_image,t_bbox,out_layer='fc5')
show_grid(init_image,t_bbox,1)

# %%
target_feat_fc5.size()
# Out:
# torch.Size([1, 512])

# %%
# iterating ........
i=i+1
image = Image.open(img_list[i]).convert('RGB')
# Estimate target bbox
samples = gen_samples(sample_generator, target_bbox, opts['n_samples'])
samples_feats_fc5 = forward_samples(model, image, samples,out_layer='fc5')

probFea = target_feat_fc5
galFea = samples_feats_fc5

diff = galFea-probFea
dist = torch.pow(diff,2).sum(dim=1)
original_dist = dist/torch.max(dist)
original_dist,initial_rank = torch.sort(original_dist)
#original_dist = original_dist.cpu().numpy()
#initial_rank = np.argsort(original_dist).astype(np.int32)

samples = samples[initial_rank,:]
target_bbox = samples[:5,:].mean(axis=0)
show_result(image,target_bbox)
original_dist[:5].mean()
# Out:
# 0.26169127225875854

# %%
sample_generator = SampleGenerator('gaussian', image.size, 1.5, 1.05, valid=True)

# %%
sample_generator = SampleGenerator('gaussian', image.size, 0.6, 1.05, valid=True)

# %%
show_grid(image,samples,40)

# %%
show_bbox(image,samples[:,:])

# %%
original_dist[initial_rank]
# Out:
# array([0.8525576 , 0.86469764, 0.8719805 , 0.88244784, 0.9049921 ,
#        0.9158246 , 0.92556185, 0.93907887, 0.94147724, 0.9652759 ,
#        0.96643305, 0.9678019 , 0.97802776, 0.9852919 , 0.98672974,
#        0.9888054 , 0.98939455, 0.9897983 , 0.9910759 , 0.99476   ,
#        0.9957331 , 0.99614584, 0.9963377 , 0.9968043 , 0.99747074,
#        0.9977826 , 0.9980238 , 0.9982776 , 0.99864095, 0.99873966,
#        0.9987477 , 0.9988475 , 0.99885124, 0.9988616 , 0.9988791 ,
#        0.9988982 , 0.9989003 , 0.9989017 , 0.99892867, 0.9989434 ,
#        0.9989479 , 0.99894917, 0.9989498 , 0.99896806, 0.9989684 ,
#        0.9989708 , 0.9989727 , 0.9989789 , 0.9989855 , 0.9989872 ,
#        0.9989895 , 0.9990081 , 0.9990129 , 0.9990265 , 0.9990279 ,
#        0.9990291 , 0.9990425 , 0.99904346, 0.999065  , 0.99906754,
#        0.9990747 , 0.99908733, 0.99908787, 0.9990886 , 0.999106  ,
#        0.99911034, 0.99911195, 0.9991163 , 0.9991325 , 0.9991528 ,
#        0.9991556 , 0.9991688 , 0.99918604, 0.9991936 , 0.99919534,
#        0.9991976 , 0.9992048 , 0.9992118 , 0.9992125 , 0.9992279 ,
#        0.9992287 , 0.999231  , 0.99923456, 0.99924093, 0.99924403,
#        0.99924576, 0.9992497 , 0.9992756 , 0.9992775 , 0.99927866,
#        0.9992827 , 0.99929184, 0.9993021 , 0.9993038 , 0.9993119 ,
#        0.9993132 , 0.99932134, 0.9993246 , 0.9993269 , 0.99932796,
#        0.9993361 , 0.9993393 , 0.99934053, 0.99934316, 0.9993451 ,
#        0.9993553 , 0.99937713, 0.99937916, 0.99938667, 0.99938846,
#        0.99939275, 0.999399  , 0.99940115, 0.99940246, 0.9994068 ,
#        0.9994074 , 0.9994156 , 0.9994174 , 0.999419  , 0.9994298 ,
#        0.9994319 , 0.9994356 , 0.99943763, 0.9994386 , 0.99944055,
#        0.9994458 , 0.9994464 , 0.9994562 , 0.9994573 , 0.9994588 ,
#        0.9994701 , 0.9994714 , 0.9994746 , 0.99949116, 0.999498  ,
#        0.9995    , 0.9995013 , 0.99950624, 0.999509  , 0.9995126 ,
#        0.9995142 , 0.99951524, 0.9995196 , 0.99952185, 0.99952906,
#        0.99952984, 0.9995372 , 0.9995391 , 0.9995397 , 0.99953973,
#        0.9995427 , 0.99954385, 0.99954975, 0.99955416, 0.9995595 ,
#        0.9995617 , 0.9995696 , 0.99957275, 0.99957573, 0.9995847 ,
#        0.9995909 , 0.99959266, 0.99959993, 0.99961066, 0.99961877,
#        0.9996204 , 0.99962187, 0.99962395, 0.9996247 , 0.9996254 ,
#        0.99963534, 0.99963814, 0.9996411 , 0.9996412 , 0.9996414 ,
#        0.99964327, 0.99964404, 0.9996445 , 0.99965185, 0.9996573 ,
#        0.9996602 , 0.99966025, 0.99966085, 0.9996629 , 0.9996679 ,
#        0.99967283, 0.99967563, 0.9996785 , 0.9996844 , 0.99968696,
#        0.999696  , 0.99969643, 0.9996984 , 0.99971354, 0.99972045,
#        0.9997232 , 0.99972373, 0.9997319 , 0.99973446, 0.9997368 ,
#        0.99973804, 0.9997385 , 0.99974406, 0.99974513, 0.9997518 ,
#        0.9997534 , 0.99976414, 0.9997668 , 0.999767  , 0.999769  ,
#        0.99977344, 0.9997758 , 0.9997768 , 0.99978006, 0.9997808 ,
#        0.9997846 , 0.9997851 , 0.99978834, 0.99979436, 0.9998009 ,
#        0.99980175, 0.9998021 , 0.999808  , 0.99981636, 0.9998201 ,
#        0.99982065, 0.9998234 , 0.99982685, 0.99983275, 0.9998378 ,
#        0.999843  , 0.9998483 , 0.9998577 , 0.9998595 , 0.999861  ,
#        0.9998653 , 0.9998657 , 0.9998742 , 0.9998879 , 0.99989796,
#        0.9999033 , 0.999905  , 0.9999081 , 0.99991006, 0.9999173 ,
#        0.9999248 , 0.99993515, 0.9999355 , 0.9999462 , 0.9999537 ,
#        0.99995923, 0.9999682 , 0.99996996, 0.99997914, 0.99999684,
#        1.        ], dtype=float32)

# %%
while True:
    # iterating ........
    i=i+1
    image = Image.open(img_list[i]).convert('RGB')
    # Estimate target bbox
    samples = gen_samples(sample_generator, target_bbox, opts['n_samples'])
    samples_feats_fc5 = forward_samples(model, image, samples,out_layer='fc5')
    samples_feats_fc5 = samples_feats_fc5.cpu().numpy()
    probFea = target_feat_fc5
    galFea = samples_feats_fc5
    query_num = probFea.shape[0]
    all_num = query_num + galFea.shape[0]    
    feat = np.append(probFea,galFea,axis = 0)
    feat = feat.astype(np.float16)
    original_dist = cdist(feat,feat).astype(np.float16)  
    original_dist = np.power(original_dist,2).astype(np.float16)
    del feat    
    gallery_num = original_dist.shape[0]
    original_dist = np.transpose(original_dist/np.max(original_dist,axis = 0))
    V = np.zeros_like(original_dist).astype(np.float16)
    initial_rank = np.argsort(original_dist).astype(np.int32)
    samples = np.concatenate([t_bbox,samples],axis=0)
    samples = samples[initial_rank[0,:],:]
    target_bbox = samples[1:6,:].mean(axis=0)
    show_result(image,target_bbox)
    original_dist[initial_rank[0,1:6],0].mean()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: overflow encountered in power
#   app.launch_new_instance()
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in divide
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
        # forward
        pos_fc5 = model(pos_feats, in_layer='fc4',out_layer='fc5')
        neg_fc5 = model(neg_feats, in_layer='fc4',out_layer='fc5')

# %%
pdist = PairwiseDistance()

# %%
d_p = pdist.forward(pos_fc5,pos_fc5)
d_p
# Out:
# Variable containing:
#  0.6762
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %%
d_n = pdist.forward(pos_fc5,neg_fc5)
d_n
# Out:
# Variable containing:
#  0.2100
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %%
a = torch.rand((4,5))
torch.sum(a)
# Out:
# 11.711203873157501

# %%
i
# Out:
# 161
